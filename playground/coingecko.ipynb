# %%
import requests
import os 
import time 

os.environ['COINMARKETCAP_API_KEY'] = 'CG-mETiggwB5XXC5scj2tZuvKRN'

BASE_URL = "https://api.coingecko.com/api/v3/"

# %%
url = BASE_URL + "coins/markets?vs_currency=usd&order=market_cap_desc"
info_url = BASE_URL + "coins/markets"
headers = {"x-cg-api-key": "CG-mETiggwB5XXC5scj2tZuvKRN"}

# %%
requests.get(url, headers=headers).json()
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 67713,
#   'market_cap': 1331358137123,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1421074061473,
#   'total_volume': 37096067378,
#   'high_24h': 68679,
#   'low_24h': 66174,
#   'price_change_24h': -261.0166878558812,
#   'price_change_percentage_24h': -0.38399,
#   'market_cap_change_24h': -5069807898.532471,
#   'market_cap_change_percentage_24h': -0.37936,
#   'circulating_supply': 19674218.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 73738,
#   'ath_change_percentage': -8.07752,
#   'ath_date': '2024-03-14T07:10:36.635Z',
#   'atl': 67.81,
#   'atl_change_percentage': 99859.79938,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:39.974Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 3338.64,
#   'market_cap': 400698176798,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 400698176798,
#   'total_volume': 16713407151,
#   'high_24h': 3343.09,
#   'low_24h': 3224.18,
#   'price_change_24h': 11.26,
#   'price_change_percentage_24h': 0.33827,
#   'market_cap_change_24h': 2302064038,
#   'market_cap_change_percentage_24h': 0.57783,
#   'circulating_supply': 120068151.521972,
#   'total_supply': 120068151.521972,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -31.46954,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 772014.90194,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 64.9306179282331,
#    'currency': 'btc',
#    'percentage': 6493.0617928233105},
#   'last_updated': '2024-04-05T20:56:08.426Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://assets.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.001,
#   'market_cap': 106623843578,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 106623843578,
#   'total_volume': 50279791832,
#   'high_24h': 1.005,
#   'low_24h': 0.993481,
#   'price_change_24h': 0.00026161,
#   'price_change_percentage_24h': 0.02614,
#   'market_cap_change_24h': 487703003,
#   'market_cap_change_percentage_24h': 0.45951,
#   'circulating_supply': 106601457935.074,
#   'total_supply': 106601457935.074,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.24348,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 75.07321,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:18.244Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://assets.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 581.72,
#   'market_cap': 89494457850,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 89494457850,
#   'total_volume': 1998304809,
#   'high_24h': 590.52,
#   'low_24h': 562.62,
#   'price_change_24h': -5.652440528094303,
#   'price_change_percentage_24h': -0.96233,
#   'market_cap_change_24h': -940954393.700119,
#   'market_cap_change_percentage_24h': -1.04047,
#   'circulating_supply': 153856150.0,
#   'total_supply': 153856150.0,
#   'max_supply': 200000000.0,
#   'ath': 686.31,
#   'ath_change_percentage': -14.93823,
#   'ath_date': '2021-05-10T07:24:17.097Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1466043.32778,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:39.945Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://assets.coingecko.com/coins/images/4128/large/solana.png?1696504756',
#   'current_price': 175.93,
#   'market_cap': 78370084927,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 100992062562,
#   'total_volume': 7203024245,
#   'high_24h': 184.79,
#   'low_24h': 169.34,
#   'price_change_24h': -6.6212207554160045,
#   'price_change_percentage_24h': -3.62704,
#   'market_cap_change_24h': -2669473228.951874,
#   'market_cap_change_percentage_24h': -3.29404,
#   'circulating_supply': 444922998.522965,
#   'total_supply': 573352591.668326,
#   'max_supply': None,
#   'ath': 259.96,
#   'ath_change_percentage': -32.09169,
#   'ath_date': '2021-11-06T21:54:35.825Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 35150.30084,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:35.508Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://assets.coingecko.com/coins/images/6319/large/usdc.png?1696506694',
#   'current_price': 1.001,
#   'market_cap': 32866277984,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 32884664602,
#   'total_volume': 13908800981,
#   'high_24h': 1.005,
#   'low_24h': 0.990039,
#   'price_change_24h': -0.00011735136086477,
#   'price_change_percentage_24h': -0.01173,
#   'market_cap_change_24h': -65250236.397872925,
#   'market_cap_change_percentage_24h': -0.19814,
#   'circulating_supply': 32876044725.5511,
#   'total_supply': 32894436807.696,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.6002,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 14.1107,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:47.230Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 0.591117,
#   'market_cap': 32520801965,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 59066106773,
#   'total_volume': 1525944683,
#   'high_24h': 0.59385,
#   'low_24h': 0.570785,
#   'price_change_24h': -0.000273990182601991,
#   'price_change_percentage_24h': -0.04633,
#   'market_cap_change_24h': 70060728,
#   'market_cap_change_percentage_24h': 0.2159,
#   'circulating_supply': 55051549471.0,
#   'total_supply': 99987715632.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -82.59214,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 21923.52314,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:32.141Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://assets.coingecko.com/coins/images/13442/large/steth_logo.png?1696513206',
#   'current_price': 3332.31,
#   'market_cap': 31856703917,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 31856703917,
#   'total_volume': 93019255,
#   'high_24h': 3336.94,
#   'low_24h': 3217.48,
#   'price_change_24h': 14.72,
#   'price_change_percentage_24h': 0.44377,
#   'market_cap_change_24h': 231081419,
#   'market_cap_change_percentage_24h': 0.73068,
#   'circulating_supply': 9563142.71201442,
#   'total_supply': 9563261.56375797,
#   'max_supply': None,
#   'ath': 4829.57,
#   'ath_change_percentage': -30.9734,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 590.35298,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:00.356Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.179081,
#   'market_cap': 25773614272,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 25775979131,
#   'total_volume': 2174825049,
#   'high_24h': 0.180295,
#   'low_24h': 0.168704,
#   'price_change_24h': -0.000905831648287447,
#   'price_change_percentage_24h': -0.50328,
#   'market_cap_change_24h': -89036930.12879181,
#   'market_cap_change_percentage_24h': -0.34427,
#   'circulating_supply': 143752296383.705,
#   'total_supply': 143765486383.705,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -75.40873,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 206915.64841,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:32.897Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://assets.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.577441,
#   'market_cap': 20361794542,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 25975940342,
#   'total_volume': 471464148,
#   'high_24h': 0.584927,
#   'low_24h': 0.562472,
#   'price_change_24h': -0.002569126029373092,
#   'price_change_percentage_24h': -0.44294,
#   'market_cap_change_24h': -80647503.22143173,
#   'market_cap_change_percentage_24h': -0.39451,
#   'circulating_supply': 35274209222.0096,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -81.2457,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 2906.99122,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:23.514Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://assets.coingecko.com/coins/images/17980/large/ton_symbol.png?1696517498',
#   'current_price': 5.46,
#   'market_cap': 18988413772,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 27930818743,
#   'total_volume': 261344672,
#   'high_24h': 5.49,
#   'low_24h': 4.98,
#   'price_change_24h': 0.447277,
#   'price_change_percentage_24h': 8.91606,
#   'market_cap_change_24h': 1587812969,
#   'market_cap_change_percentage_24h': 9.12505,
#   'circulating_supply': 3470556528.62227,
#   'total_supply': 5104980674.08397,
#   'max_supply': None,
#   'ath': 5.69,
#   'ath_change_percentage': -3.42996,
#   'ath_date': '2024-03-25T14:26:09.974Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 957.09651,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:08.680Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://assets.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 45.46,
#   'market_cap': 17171405027,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 19838366324,
#   'total_volume': 491085816,
#   'high_24h': 46.62,
#   'low_24h': 44.09,
#   'price_change_24h': -1.0912279996230296,
#   'price_change_percentage_24h': -2.34411,
#   'market_cap_change_24h': -394865788.09936714,
#   'market_cap_change_percentage_24h': -2.24786,
#   'circulating_supply': 377877260.44885,
#   'total_supply': 436566926.628179,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -68.53671,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 1528.29409,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:45.642Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://assets.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 2.696e-05,
#   'market_cap': 15902622512,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 26986750465,
#   'total_volume': 643167432,
#   'high_24h': 2.773e-05,
#   'low_24h': 2.637e-05,
#   'price_change_24h': -6.68043381036e-07,
#   'price_change_percentage_24h': -2.41774,
#   'market_cap_change_24h': -374768854.2931957,
#   'market_cap_change_percentage_24h': -2.30239,
#   'circulating_supply': 589264797190368.6,
#   'total_supply': 999982363113915.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -68.62521,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 47957805.54034,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:31.277Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://assets.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 666.3,
#   'market_cap': 13104923664,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 13978378967,
#   'total_volume': 1810828577,
#   'high_24h': 708.27,
#   'low_24h': 628.35,
#   'price_change_24h': 22.38,
#   'price_change_percentage_24h': 3.47484,
#   'market_cap_change_24h': 489581645,
#   'market_cap_change_percentage_24h': 3.88084,
#   'circulating_supply': 19687790.5216508,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -82.42684,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 764.74275,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:36.607Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://assets.coingecko.com/coins/images/12171/large/polkadot.png?1696512008',
#   'current_price': 8.42,
#   'market_cap': 11360265217,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 12041775771,
#   'total_volume': 239576360,
#   'high_24h': 8.51,
#   'low_24h': 8.13,
#   'price_change_24h': -0.04214517954440922,
#   'price_change_percentage_24h': -0.49799,
#   'market_cap_change_24h': -46503067.61419296,
#   'market_cap_change_percentage_24h': -0.40768,
#   'circulating_supply': 1349380422.48664,
#   'total_supply': 1430330733.17567,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -84.65765,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 212.71567,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:02.615Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1696507857',
#   'current_price': 67707,
#   'market_cap': 10503004971,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 10503004971,
#   'total_volume': 359138799,
#   'high_24h': 68588,
#   'low_24h': 66190,
#   'price_change_24h': -186.46035774305346,
#   'price_change_percentage_24h': -0.27464,
#   'market_cap_change_24h': -42638046.06555557,
#   'market_cap_change_percentage_24h': -0.40432,
#   'circulating_supply': 155266.89789822,
#   'total_supply': 155266.89789822,
#   'max_supply': 155266.89789822,
#   'ath': 73505,
#   'ath_change_percentage': -8.03414,
#   'ath_date': '2024-03-14T07:10:23.403Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 2053.43191,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:38.494Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://assets.coingecko.com/coins/images/1094/large/tron-logo.png?1696502193',
#   'current_price': 0.118111,
#   'market_cap': 10353923044,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 10353947718,
#   'total_volume': 355168205,
#   'high_24h': 0.119637,
#   'low_24h': 0.117248,
#   'price_change_24h': -0.000848765794073059,
#   'price_change_percentage_24h': -0.71349,
#   'market_cap_change_24h': -52040534.803281784,
#   'market_cap_change_percentage_24h': -0.5001,
#   'circulating_supply': 87694025359.0125,
#   'total_supply': 87694001638.7944,
#   'max_supply': None,
#   'ath': 0.231673,
#   'ath_change_percentage': -48.88371,
#   'ath_date': '2018-01-05T00:00:00.000Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 6463.19869,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 61.163588839207314,
#    'currency': 'usd',
#    'percentage': 6116.358883920731},
#   'last_updated': '2024-04-05T20:57:07.124Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1696502009',
#   'current_price': 17.4,
#   'market_cap': 10219676730,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 17407046891,
#   'total_volume': 418205497,
#   'high_24h': 17.79,
#   'low_24h': 16.96,
#   'price_change_24h': -0.3091023635948531,
#   'price_change_percentage_24h': -1.74518,
#   'market_cap_change_24h': -163846933.02926445,
#   'market_cap_change_percentage_24h': -1.57795,
#   'circulating_supply': 587099971.3083414,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -66.88522,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 11676.21067,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:56.915Z'},
#  {'id': 'matic-network',
#   'symbol': 'matic',
#   'name': 'Polygon',
#   'image': 'https://assets.coingecko.com/coins/images/4713/large/polygon.png?1698233745',
#   'current_price': 0.890647,
#   'market_cap': 8268213327,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 8906887420,
#   'total_volume': 283832930,
#   'high_24h': 0.907281,
#   'low_24h': 0.86346,
#   'price_change_24h': -0.009651536222925472,
#   'price_change_percentage_24h': -1.07204,
#   'market_cap_change_24h': -63649763.59151554,
#   'market_cap_change_percentage_24h': -0.76393,
#   'circulating_supply': 9282943566.203985,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.92,
#   'ath_change_percentage': -69.39868,
#   'ath_date': '2021-12-27T02:08:34.307Z',
#   'atl': 0.00314376,
#   'atl_change_percentage': 28286.86293,
#   'atl_date': '2019-05-10T00:00:00.000Z',
#   'roi': {'times': 337.64910114181004,
#    'currency': 'usd',
#    'percentage': 33764.910114181},
#   'last_updated': '2024-04-05T20:56:20.381Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://assets.coingecko.com/coins/images/12504/large/uni.jpg?1696512319',
#   'current_price': 10.99,
#   'market_cap': 8265783633,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 10965971294,
#   'total_volume': 154700202,
#   'high_24h': 11.05,
#   'low_24h': 10.51,
#   'price_change_24h': 0.03079381,
#   'price_change_percentage_24h': 0.281,
#   'market_cap_change_24h': 4943343,
#   'market_cap_change_percentage_24h': 0.05984,
#   'circulating_supply': 753766667.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -75.54422,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 966.33405,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:31.334Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://assets.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1696514180',
#   'current_price': 17.08,
#   'market_cap': 7894096175,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 8834283323,
#   'total_volume': 267486958,
#   'high_24h': 17.95,
#   'low_24h': 16.64,
#   'price_change_24h': -0.6451366183098592,
#   'price_change_percentage_24h': -3.63973,
#   'market_cap_change_24h': -294002475.803236,
#   'market_cap_change_percentage_24h': -3.59061,
#   'circulating_supply': 461981024.111331,
#   'total_supply': 517002981.310408,
#   'max_supply': None,
#   'ath': 700.65,
#   'ath_change_percentage': -97.55754,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 2.87,
#   'atl_change_percentage': 497.30996,
#   'atl_date': '2023-09-22T00:29:57.369Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:45.620Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 7.4,
#   'market_cap': 7865477859,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 8787933569,
#   'total_volume': 811319104,
#   'high_24h': 7.49,
#   'low_24h': 6.51,
#   'price_change_24h': 0.740842,
#   'price_change_percentage_24h': 11.12353,
#   'market_cap_change_24h': 938640563,
#   'market_cap_change_percentage_24h': 13.55078,
#   'circulating_supply': 1059042661.6857,
#   'total_supply': 1183246170.6779,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -63.59788,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 1312.38412,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:39.664Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://assets.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 99.41,
#   'market_cap': 7392379587,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 8347398831,
#   'total_volume': 893136865,
#   'high_24h': 99.83,
#   'low_24h': 95.54,
#   'price_change_24h': 1.27,
#   'price_change_percentage_24h': 1.28922,
#   'market_cap_change_24h': 110807263,
#   'market_cap_change_percentage_24h': 1.52175,
#   'circulating_supply': 74389626.9834713,
#   'total_supply': 84000000.0,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -75.7145,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 8572.52619,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:17.699Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://assets.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 5.77,
#   'market_cap': 5344398694,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 5681757126,
#   'total_volume': 2666128,
#   'high_24h': 5.89,
#   'low_24h': 5.58,
#   'price_change_24h': -0.06744398577294763,
#   'price_change_percentage_24h': -1.15516,
#   'market_cap_change_24h': -77814439.61851788,
#   'market_cap_change_percentage_24h': -1.4351,
#   'circulating_supply': 926740196.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 8.14,
#   'ath_change_percentage': -28.90818,
#   'ath_date': '2022-02-08T17:40:10.285Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 623.07282,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:12.378Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'image': 'https://assets.coingecko.com/coins/images/26455/large/aptos_round.png?1696525528',
#   'current_price': 13.29,
#   'market_cap': 5286577975,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 14465296057,
#   'total_volume': 305056936,
#   'high_24h': 14.17,
#   'low_24h': 12.65,
#   'price_change_24h': -0.8694072739303937,
#   'price_change_percentage_24h': -6.14212,
#   'market_cap_change_24h': -349816992.09415436,
#   'market_cap_change_percentage_24h': -6.2064,
#   'circulating_supply': 398142003.597805,
#   'total_supply': 1089408305.65193,
#   'max_supply': None,
#   'ath': 19.92,
#   'ath_change_percentage': -33.26626,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 3.08,
#   'atl_change_percentage': 331.63992,
#   'atl_date': '2022-12-29T21:35:14.796Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:16.206Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://assets.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999255,
#   'market_cap': 5051177677,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 5051179508,
#   'total_volume': 802856320,
#   'high_24h': 1.002,
#   'low_24h': 0.994758,
#   'price_change_24h': 0.00044181,
#   'price_change_percentage_24h': 0.04423,
#   'market_cap_change_24h': 108885928,
#   'market_cap_change_percentage_24h': 2.20315,
#   'circulating_supply': 5054183356.8793,
#   'total_supply': 5054185189.23192,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -18.04689,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.26496,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:18.537Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://assets.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1696501717',
#   'current_price': 33.65,
#   'market_cap': 4919133937,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 7079616948,
#   'total_volume': 449849214,
#   'high_24h': 33.97,
#   'low_24h': 31.79,
#   'price_change_24h': 0.682681,
#   'price_change_percentage_24h': 2.07104,
#   'market_cap_change_24h': 113042667,
#   'market_cap_change_percentage_24h': 2.35207,
#   'circulating_supply': 146400790.905334,
#   'total_supply': 210700000.0,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -79.79478,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 5389.08607,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 73.76849783796338,
#    'currency': 'usd',
#    'percentage': 7376.849783796338},
#   'last_updated': '2024-04-05T20:56:40.433Z'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'image': 'https://assets.coingecko.com/coins/images/2069/large/Stacks_Logo_png.png?1709979332',
#   'current_price': 3.11,
#   'market_cap': 4517334890,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 5657440480,
#   'total_volume': 124910508,
#   'high_24h': 3.34,
#   'low_24h': 2.92,
#   'price_change_24h': -0.16368300942238934,
#   'price_change_percentage_24h': -4.99277,
#   'market_cap_change_24h': -247255131.0530529,
#   'market_cap_change_percentage_24h': -5.18943,
#   'circulating_supply': 1451630796.5333,
#   'total_supply': 1818000000.0,
#   'max_supply': 1818000000.0,
#   'ath': 3.86,
#   'ath_change_percentage': -19.28368,
#   'ath_date': '2024-04-01T12:34:58.342Z',
#   'atl': 0.04559639,
#   'atl_change_percentage': 6740.75734,
#   'atl_date': '2020-03-13T02:29:26.415Z',
#   'roi': {'times': 24.95598618066219,
#    'currency': 'usd',
#    'percentage': 2495.5986180662194},
#   'last_updated': '2024-04-05T20:56:03.957Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'image': 'https://assets.coingecko.com/coins/images/12817/large/filecoin.png?1696512609',
#   'current_price': 8.44,
#   'market_cap': 4499276474,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 16560960783,
#   'total_volume': 261917159,
#   'high_24h': 8.64,
#   'low_24h': 8.14,
#   'price_change_24h': -0.153331459444777,
#   'price_change_percentage_24h': -1.7846,
#   'market_cap_change_24h': -67172336.76184368,
#   'market_cap_change_percentage_24h': -1.471,
#   'circulating_supply': 532699246.0,
#   'total_supply': 1960762219.0,
#   'max_supply': 1960762526.0,
#   'ath': 236.84,
#   'ath_change_percentage': -96.42453,
#   'ath_date': '2021-04-01T13:29:41.564Z',
#   'atl': 2.64,
#   'atl_change_percentage': 220.64586,
#   'atl_date': '2022-12-16T22:45:28.552Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:46.005Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://assets.coingecko.com/coins/images/30980/large/token-logo.png?1696529819',
#   'current_price': 1.35,
#   'market_cap': 4303238760,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 8395919592,
#   'total_volume': 131211008,
#   'high_24h': 1.47,
#   'low_24h': 1.29,
#   'price_change_24h': 0.00624828,
#   'price_change_percentage_24h': 0.46432,
#   'market_cap_change_24h': -35710458.105451584,
#   'market_cap_change_percentage_24h': -0.82302,
#   'circulating_supply': 3187644283.73314,
#   'total_supply': 6219316794.99,
#   'max_supply': 6219316794.99,
#   'ath': 1.47,
#   'ath_change_percentage': -7.99825,
#   'ath_date': '2024-03-27T13:05:36.937Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 339.63331,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:42.532Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos Hub',
#   'image': 'https://assets.coingecko.com/coins/images/1481/large/cosmos_hub.png?1696502525',
#   'current_price': 10.98,
#   'market_cap': 4290363000,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 4293016859,
#   'total_volume': 174281180,
#   'high_24h': 11.05,
#   'low_24h': 10.64,
#   'price_change_24h': 0.00584439,
#   'price_change_percentage_24h': 0.05325,
#   'market_cap_change_24h': 7129313,
#   'market_cap_change_percentage_24h': 0.16645,
#   'circulating_supply': 390688369.813272,
#   'total_supply': 390930035.085365,
#   'max_supply': None,
#   'ath': 44.45,
#   'ath_change_percentage': -75.23672,
#   'ath_date': '2022-01-17T00:34:41.497Z',
#   'atl': 1.16,
#   'atl_change_percentage': 848.81318,
#   'atl_date': '2020-03-13T02:27:44.591Z',
#   'roi': {'times': 108.8207058564569,
#    'currency': 'usd',
#    'percentage': 10882.07058564569},
#   'last_updated': '2024-04-05T20:57:23.587Z'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'image': 'https://assets.coingecko.com/coins/images/16547/large/photo_2023-03-29_21.47.00.jpeg?1696516109',
#   'current_price': 1.44,
#   'market_cap': 3819404236,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 14391452418,
#   'total_volume': 324918943,
#   'high_24h': 1.47,
#   'low_24h': 1.4,
#   'price_change_24h': -0.02478768739082771,
#   'price_change_percentage_24h': -1.69347,
#   'market_cap_change_24h': -71535421.80062819,
#   'market_cap_change_percentage_24h': -1.83851,
#   'circulating_supply': 2653939384.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.39,
#   'ath_change_percentage': -39.63055,
#   'ath_date': '2024-01-12T12:29:59.231Z',
#   'atl': 0.744925,
#   'atl_change_percentage': 93.71087,
#   'atl_date': '2023-09-11T19:40:49.196Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:46.702Z'},
#  {'id': 'immutable-x',
#   'symbol': 'imx',
#   'name': 'Immutable',
#   'image': 'https://assets.coingecko.com/coins/images/17233/large/immutableX-symbol-BLK-RGB.png?1696516787',
#   'current_price': 2.67,
#   'market_cap': 3795221815,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 5334038786,
#   'total_volume': 54218111,
#   'high_24h': 2.8,
#   'low_24h': 2.6,
#   'price_change_24h': -0.13064651327297572,
#   'price_change_percentage_24h': -4.67206,
#   'market_cap_change_24h': -182155813.69254255,
#   'market_cap_change_percentage_24h': -4.5798,
#   'circulating_supply': 1423019954.3898141,
#   'total_supply': 2000000000.0,
#   'max_supply': 2000000000.0,
#   'ath': 9.52,
#   'ath_change_percentage': -71.90337,
#   'ath_date': '2021-11-26T01:03:01.536Z',
#   'atl': 0.378055,
#   'atl_change_percentage': 607.51148,
#   'atl_date': '2022-12-31T07:36:37.649Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:22.189Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://assets.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 0.141975,
#   'market_cap': 3779584848,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 4256943094,
#   'total_volume': 18031930,
#   'high_24h': 0.14581,
#   'low_24h': 0.139933,
#   'price_change_24h': -0.002345825928546042,
#   'price_change_percentage_24h': -1.62543,
#   'market_cap_change_24h': -61940673.635157585,
#   'market_cap_change_percentage_24h': -1.6124,
#   'circulating_supply': 26635908200.135,
#   'total_supply': 30000000000.0,
#   'max_supply': None,
#   'ath': 0.965407,
#   'ath_change_percentage': -85.28971,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 1071.77292,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:13.076Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://assets.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 577.63,
#   'market_cap': 3764395266,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 12080106362,
#   'total_volume': 23540971,
#   'high_24h': 609.05,
#   'low_24h': 562.9,
#   'price_change_24h': -28.07002640522262,
#   'price_change_percentage_24h': -4.63428,
#   'market_cap_change_24h': -191116421.63544464,
#   'market_cap_change_percentage_24h': -4.83165,
#   'circulating_supply': 6544007.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -23.82083,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
#   'atl_change_percentage': 1772.0003,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:00.160Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://assets.coingecko.com/coins/images/100/large/Stellar_symbol_black_RGB.png?1696501482',
#   'current_price': 0.128037,
#   'market_cap': 3692726084,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 6401110227,
#   'total_volume': 86343080,
#   'high_24h': 0.12956,
#   'low_24h': 0.124573,
#   'price_change_24h': -0.000635436540547263,
#   'price_change_percentage_24h': -0.49384,
#   'market_cap_change_24h': -14033638.96418333,
#   'market_cap_change_percentage_24h': -0.3786,
#   'circulating_supply': 28845449710.221,
#   'total_supply': 50001787007.7091,
#   'max_supply': 50001787007.7091,
#   'ath': 0.875563,
#   'ath_change_percentage': -85.35796,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 26825.84849,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:41.484Z'},
#  {'id': 'render-token',
#   'symbol': 'rndr',
#   'name': 'Render',
#   'image': 'https://assets.coingecko.com/coins/images/11636/large/rndr.png?1696511529',
#   'current_price': 9.32,
#   'market_cap': 3559453883,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 4959561272,
#   'total_volume': 177938819,
#   'high_24h': 9.64,
#   'low_24h': 8.82,
#   'price_change_24h': -0.3058580238897921,
#   'price_change_percentage_24h': -3.1779,
#   'market_cap_change_24h': -111522303.80407763,
#   'market_cap_change_percentage_24h': -3.03795,
#   'circulating_supply': 381861234.292815,
#   'total_supply': 532065943.572815,
#   'max_supply': 532065943.572815,
#   'ath': 13.53,
#   'ath_change_percentage': -31.0245,
#   'ath_date': '2024-03-17T16:30:24.636Z',
#   'atl': 0.03665669,
#   'atl_change_percentage': 25367.71539,
#   'atl_date': '2020-06-16T13:22:25.900Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:32.500Z'},
#  {'id': 'first-digital-usd',
#   'symbol': 'fdusd',
#   'name': 'First Digital USD',
#   'image': 'https://assets.coingecko.com/coins/images/31079/large/firstfigital.jpeg?1696529912',
#   'current_price': 1.004,
#   'market_cap': 3536633269,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 3536633269,
#   'total_volume': 8728039482,
#   'high_24h': 1.013,
#   'low_24h': 0.990703,
#   'price_change_24h': -0.002983843514677176,
#   'price_change_percentage_24h': -0.29644,
#   'market_cap_change_24h': 639264629,
#   'market_cap_change_percentage_24h': 22.06363,
#   'circulating_supply': 3524419341.81,
#   'total_supply': 3524419341.81,
#   'max_supply': None,
#   'ath': 1.041,
#   'ath_change_percentage': -3.57384,
#   'ath_date': '2023-10-23T22:55:15.103Z',
#   'atl': 0.942129,
#   'atl_change_percentage': 6.58082,
#   'atl_date': '2023-08-17T21:55:41.478Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:40.841Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://assets.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.104641,
#   'market_cap': 3526147749,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 5228632612,
#   'total_volume': 48211329,
#   'high_24h': 0.105344,
#   'low_24h': 0.10055,
#   'price_change_24h': -0.000132005334222959,
#   'price_change_percentage_24h': -0.12599,
#   'market_cap_change_24h': -705742.0925955772,
#   'market_cap_change_percentage_24h': -0.02001,
#   'circulating_supply': 33719597559.5063,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -81.62183,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 960.87296,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:22.355Z'},
#  {'id': 'maker',
#   'symbol': 'mkr',
#   'name': 'Maker',
#   'image': 'https://assets.coingecko.com/coins/images/1364/large/Mark_Maker.png?1696502423',
#   'current_price': 3699.15,
#   'market_cap': 3423228972,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 3619490076,
#   'total_volume': 173276261,
#   'high_24h': 3987.32,
#   'low_24h': 3687.45,
#   'price_change_24h': -223.72794662839033,
#   'price_change_percentage_24h': -5.70316,
#   'market_cap_change_24h': -203207469.13806581,
#   'market_cap_change_percentage_24h': -5.6035,
#   'circulating_supply': 924620.545754508,
#   'total_supply': 977631.036950888,
#   'max_supply': 1005577.0,
#   'ath': 6292.31,
#   'ath_change_percentage': -40.97931,
#   'ath_date': '2021-05-03T21:54:29.333Z',
#   'atl': 168.36,
#   'atl_change_percentage': 2105.88077,
#   'atl_date': '2020-03-16T20:52:36.527Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:29.727Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://assets.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 56.63,
#   'market_cap': 3398395488,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 13364625550,
#   'total_volume': 9723802,
#   'high_24h': 57.36,
#   'low_24h': 54.7,
#   'price_change_24h': 0.793708,
#   'price_change_percentage_24h': 1.42156,
#   'market_cap_change_24h': 50964419,
#   'market_cap_change_percentage_24h': 1.52249,
#   'circulating_supply': 60000000.0,
#   'total_supply': 235957685.3,
#   'max_supply': 300000000.0,
#   'ath': 73.8,
#   'ath_change_percentage': -23.17439,
#   'ath_date': '2024-03-14T00:30:12.502Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 9665.60259,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:55:52.280Z'},
#  {'id': 'dogwifcoin',
#   'symbol': 'wif',
#   'name': 'dogwifhat',
#   'image': 'https://assets.coingecko.com/coins/images/33566/large/dogwifhat.jpg?1702499428',
#   'current_price': 3.36,
#   'market_cap': 3358903364,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 3358903364,
#   'total_volume': 489659739,
#   'high_24h': 3.6,
#   'low_24h': 3.22,
#   'price_change_24h': -0.22878807125824308,
#   'price_change_percentage_24h': -6.36863,
#   'market_cap_change_24h': -229817079.85292864,
#   'market_cap_change_percentage_24h': -6.40387,
#   'circulating_supply': 998926392.0,
#   'total_supply': 998926392.0,
#   'max_supply': 998926392.0,
#   'ath': 4.83,
#   'ath_change_percentage': -30.32386,
#   'ath_date': '2024-03-31T09:34:58.366Z',
#   'atl': 0.00155464,
#   'atl_change_percentage': 216168.51021,
#   'atl_date': '2023-12-13T07:13:50.873Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:08.218Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://assets.coingecko.com/coins/images/13397/large/Graph_Token.png?1696513159',
#   'current_price': 0.334277,
#   'market_cap': 3162170579,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 3607214002,
#   'total_volume': 91024201,
#   'high_24h': 0.339258,
#   'low_24h': 0.31777,
#   'price_change_24h': -0.004255329077253956,
#   'price_change_percentage_24h': -1.25699,
#   'market_cap_change_24h': -24529399.859728336,
#   'market_cap_change_percentage_24h': -0.76974,
#   'circulating_supply': 9457024131.31199,
#   'total_supply': 10788004319.0,
#   'max_supply': 10788004319.0,
#   'ath': 2.84,
#   'ath_change_percentage': -88.20746,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.052051,
#   'atl_change_percentage': 543.76372,
#   'atl_date': '2022-11-22T10:05:03.503Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:11.723Z'},
#  {'id': 'injective-protocol',
#   'symbol': 'inj',
#   'name': 'Injective',
#   'image': 'https://assets.coingecko.com/coins/images/12882/large/Secondary_Symbol.png?1696512670',
#   'current_price': 34.44,
#   'market_cap': 3110806192,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 3454830536,
#   'total_volume': 146555837,
#   'high_24h': 34.59,
#   'low_24h': 30.95,
#   'price_change_24h': 1.44,
#   'price_change_percentage_24h': 4.3511,
#   'market_cap_change_24h': 181434503,
#   'market_cap_change_percentage_24h': 6.19363,
#   'circulating_supply': 90042222.33,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 52.62,
#   'ath_change_percentage': -34.27939,
#   'ath_date': '2024-03-14T15:06:22.124Z',
#   'atl': 0.657401,
#   'atl_change_percentage': 5160.50819,
#   'atl_date': '2020-11-03T16:19:30.576Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:19.581Z'},
#  {'id': 'kaspa',
#   'symbol': 'kas',
#   'name': 'Kaspa',
#   'image': 'https://assets.coingecko.com/coins/images/25751/large/kaspa-icon-exchanges.png?1696524837',
#   'current_price': 0.13143,
#   'market_cap': 3028648368,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 3049283050,
#   'total_volume': 43719243,
#   'high_24h': 0.134439,
#   'low_24h': 0.126473,
#   'price_change_24h': 0.00265325,
#   'price_change_percentage_24h': 2.06036,
#   'market_cap_change_24h': 65366306,
#   'market_cap_change_percentage_24h': 2.20588,
#   'circulating_supply': 23088387840.5108,
#   'total_supply': 23246067753.934,
#   'max_supply': 28704026601.0,
#   'ath': 0.189044,
#   'ath_change_percentage': -30.64762,
#   'ath_date': '2024-02-20T06:54:58.731Z',
#   'atl': 0.00017105,
#   'atl_change_percentage': 76548.03482,
#   'atl_date': '2022-05-26T14:42:59.316Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:47.216Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://assets.coingecko.com/coins/images/1167/large/VET_Token_Icon.png?1710013505',
#   'current_price': 0.04056593,
#   'market_cap': 2951902978,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 3490630347,
#   'total_volume': 80261830,
#   'high_24h': 0.04201709,
#   'low_24h': 0.03912611,
#   'price_change_24h': -0.00101694724974364,
#   'price_change_percentage_24h': -2.44559,
#   'market_cap_change_24h': -70396212.4600997,
#   'market_cap_change_percentage_24h': -2.32923,
#   'circulating_supply': 72714516834.0,
#   'total_supply': 85985041177.0,
#   'max_supply': 86712634466.0,
#   'ath': 0.280991,
#   'ath_change_percentage': -85.50719,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 2024.18696,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 3.2526737159977954,
#    'currency': 'eth',
#    'percentage': 325.26737159977955},
#   'last_updated': '2024-04-05T20:57:22.884Z'},
#  {'id': 'optimism',
#   'symbol': 'op',
#   'name': 'Optimism',
#   'image': 'https://assets.coingecko.com/coins/images/25244/large/Optimism.png?1696524385',
#   'current_price': 2.92,
#   'market_cap': 2935468778,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 12530783340,
#   'total_volume': 245617976,
#   'high_24h': 3.12,
#   'low_24h': 2.88,
#   'price_change_24h': -0.19747982642888928,
#   'price_change_percentage_24h': -6.34347,
#   'market_cap_change_24h': -190220152.4017253,
#   'market_cap_change_percentage_24h': -6.0857,
#   'circulating_supply': 1006141600.0,
#   'total_supply': 4294967296.0,
#   'max_supply': 4294967296.0,
#   'ath': 4.84,
#   'ath_change_percentage': -39.6759,
#   'ath_date': '2024-03-06T08:35:50.817Z',
#   'atl': 0.402159,
#   'atl_change_percentage': 626.64929,
#   'atl_date': '2022-06-18T20:54:52.178Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:47.141Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://assets.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 6.7e-06,
#   'market_cap': 2819157616,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 2819157616,
#   'total_volume': 439545316,
#   'high_24h': 6.95e-06,
#   'low_24h': 6.39e-06,
#   'price_change_24h': -2.00166973449e-07,
#   'price_change_percentage_24h': -2.90212,
#   'market_cap_change_24h': -76830620.20279217,
#   'market_cap_change_percentage_24h': -2.653,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 1.064e-05,
#   'ath_change_percentage': -36.9227,
#   'ath_date': '2024-03-14T07:01:12.472Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 12068.58188,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:45.852Z'},
#  {'id': 'fetch-ai',
#   'symbol': 'fet',
#   'name': 'Fetch.ai',
#   'image': 'https://assets.coingecko.com/coins/images/5681/large/Fetch.jpg?1696506140',
#   'current_price': 2.63,
#   'market_cap': 2745687296,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 3033908616,
#   'total_volume': 292557294,
#   'high_24h': 2.71,
#   'low_24h': 2.52,
#   'price_change_24h': -0.07867737606240643,
#   'price_change_percentage_24h': -2.90998,
#   'market_cap_change_24h': -83727640.66691399,
#   'market_cap_change_percentage_24h': -2.95919,
#   'circulating_supply': 1043462805.0,
#   'total_supply': 1152997575.0,
#   'max_supply': 1152997575.0,
#   'ath': 3.45,
#   'ath_change_percentage': -23.62837,
#   'ath_date': '2024-03-28T17:21:18.050Z',
#   'atl': 0.00816959,
#   'atl_change_percentage': 32190.34096,
#   'atl_date': '2020-03-13T02:24:18.347Z',
#   'roi': {'times': 29.27712866221345,
#    'currency': 'usd',
#    'percentage': 2927.712866221345},
#   'last_updated': '2024-04-05T20:57:47.058Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://assets.coingecko.com/coins/images/2538/large/theta-token-logo.png?1696503349',
#   'current_price': 2.6,
#   'market_cap': 2595323173,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 2595323173,
#   'total_volume': 47192202,
#   'high_24h': 2.62,
#   'low_24h': 2.47,
#   'price_change_24h': 0.04053366,
#   'price_change_percentage_24h': 1.58572,
#   'market_cap_change_24h': 41051371,
#   'market_cap_change_percentage_24h': 1.60717,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 15.72,
#   'ath_change_percentage': -83.45384,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 6338.17536,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 16.3113067105092,
#    'currency': 'usd',
#    'percentage': 1631.13067105092},
#   'last_updated': '2024-04-05T20:56:05.328Z'},
#  {'id': 'thorchain',
#   'symbol': 'rune',
#   'name': 'THORChain',
#   'image': 'https://assets.coingecko.com/coins/images/6595/large/Rune200x200.png?1696506946',
#   'current_price': 7.46,
#   'market_cap': 2492027786,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 3093875932,
#   'total_volume': 367658766,
#   'high_24h': 7.6,
#   'low_24h': 7.01,
#   'price_change_24h': -0.09331769365728348,
#   'price_change_percentage_24h': -1.23565,
#   'market_cap_change_24h': -13536161.915568829,
#   'market_cap_change_percentage_24h': -0.54024,
#   'circulating_supply': 334365754.0,
#   'total_supply': 415118092.0,
#   'max_supply': 500000000.0,
#   'ath': 20.87,
#   'ath_change_percentage': -64.19647,
#   'ath_date': '2021-05-19T00:30:09.436Z',
#   'atl': 0.00851264,
#   'atl_change_percentage': 87667.45861,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 195.28365289373775,
#    'currency': 'usd',
#    'percentage': 19528.365289373778},
#   'last_updated': '2024-04-05T20:56:19.530Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://assets.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 128.92,
#   'market_cap': 2333531538,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': None,
#   'total_volume': 48936488,
#   'high_24h': 132.08,
#   'low_24h': 125.95,
#   'price_change_24h': -1.9469333766700174,
#   'price_change_percentage_24h': -1.48775,
#   'market_cap_change_24h': -46141101.07532883,
#   'market_cap_change_percentage_24h': -1.93897,
#   'circulating_supply': 18147820.3764146,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -76.28037,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 59405.77462,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:28.161Z'},
#  {'id': 'lido-dao',
#   'symbol': 'ldo',
#   'name': 'Lido DAO',
#   'image': 'https://assets.coingecko.com/coins/images/13573/large/Lido_DAO.png?1696513326',
#   'current_price': 2.59,
#   'market_cap': 2313485743,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 2594399605,
#   'total_volume': 124799638,
#   'high_24h': 2.64,
#   'low_24h': 2.38,
#   'price_change_24h': 0.0039332,
#   'price_change_percentage_24h': 0.15188,
#   'market_cap_change_24h': 10959443,
#   'market_cap_change_percentage_24h': 0.47597,
#   'circulating_supply': 891722978.525582,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 7.3,
#   'ath_change_percentage': -64.43863,
#   'ath_date': '2021-08-20T08:35:20.158Z',
#   'atl': 0.40615,
#   'atl_change_percentage': 539.41967,
#   'atl_date': '2022-06-18T20:55:12.035Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:26.934Z'},
#  {'id': 'coredaoorg',
#   'symbol': 'core',
#   'name': 'Core',
#   'image': 'https://assets.coingecko.com/coins/images/28938/large/file_589.jpg?1701868471',
#   'current_price': 2.62,
#   'market_cap': 2301960934,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 5507159683,
#   'total_volume': 371450060,
#   'high_24h': 2.82,
#   'low_24h': 2.27,
# ...
#   'price_change_24h': -1.7275194446e-08,
#   'price_change_percentage_24h': -1.20267,
#   'market_cap_change_24h': -18201218.585859776,
#   'market_cap_change_percentage_24h': -1.30898,
#   'circulating_supply': 968246428571000.0,
#   'total_supply': 990000000000000.0,
#   'max_supply': 990000000000000.0,
#   'ath': 3.43e-06,
#   'ath_change_percentage': -58.60804,
#   'ath_date': '2022-01-21T04:00:31.909Z',
#   'atl': 3.65368e-07,
#   'atl_change_percentage': 288.73121,
#   'atl_date': '2023-10-13T05:10:41.241Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:41.762Z'},
#  {'id': 'the-sandbox',
#   'symbol': 'sand',
#   'name': 'The Sandbox',
#   'image': 'https://assets.coingecko.com/coins/images/12129/large/sandbox_logo.jpg?1696511971',
#   'current_price': 0.606931,
#   'market_cap': 1366604287,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 1820737545,
#   'total_volume': 106328458,
#   'high_24h': 0.609248,
#   'low_24h': 0.582342,
#   'price_change_24h': 0.00270608,
#   'price_change_percentage_24h': 0.44786,
#   'market_cap_change_24h': 8891896,
#   'market_cap_change_percentage_24h': 0.65492,
#   'circulating_supply': 2251731926.2233224,
#   'total_supply': 3000000000.0,
#   'max_supply': 3000000000.0,
#   'ath': 8.4,
#   'ath_change_percentage': -92.74945,
#   'ath_date': '2021-11-25T06:04:40.957Z',
#   'atl': 0.02897764,
#   'atl_change_percentage': 2000.97835,
#   'atl_date': '2020-11-04T15:59:14.441Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:16.207Z'},
#  {'id': 'ecash',
#   'symbol': 'xec',
#   'name': 'eCash',
#   'image': 'https://assets.coingecko.com/coins/images/16646/large/Logo_final-22.png?1696516207',
#   'current_price': 6.92e-05,
#   'market_cap': 1363052019,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 1454313319,
#   'total_volume': 62112104,
#   'high_24h': 7.438e-05,
#   'low_24h': 6.471e-05,
#   'price_change_24h': 3.66e-06,
#   'price_change_percentage_24h': 5.59088,
#   'market_cap_change_24h': 75785701,
#   'market_cap_change_percentage_24h': 5.88734,
#   'circulating_supply': 19682204673092.0,
#   'total_supply': 21000000000000.0,
#   'max_supply': 21000000000000.0,
#   'ath': 0.00038001,
#   'ath_change_percentage': -81.74289,
#   'ath_date': '2021-09-04T17:09:31.137Z',
#   'atl': 1.847e-05,
#   'atl_change_percentage': 275.63488,
#   'atl_date': '2021-07-20T20:49:46.212Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:38.179Z'},
#  {'id': 'dydx-chain',
#   'symbol': 'dydx',
#   'name': 'dYdX',
#   'image': 'https://assets.coingecko.com/coins/images/32594/large/dydx.png?1698673495',
#   'current_price': 2.93,
#   'market_cap': 1360991648,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 2083546577,
#   'total_volume': 10440123,
#   'high_24h': 2.99,
#   'low_24h': 2.81,
#   'price_change_24h': -0.056434702779565526,
#   'price_change_percentage_24h': -1.89007,
#   'market_cap_change_24h': -22882307.77023363,
#   'market_cap_change_percentage_24h': -1.6535,
#   'circulating_supply': 464677529.0,
#   'total_supply': 711376353.0,
#   'max_supply': 1000000000.0,
#   'ath': 4.52,
#   'ath_change_percentage': -35.17391,
#   'ath_date': '2024-03-07T22:19:11.131Z',
#   'atl': 2.3,
#   'atl_change_percentage': 27.18438,
#   'atl_date': '2024-01-03T12:14:30.340Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:02.859Z'},
#  {'id': 'singularitynet',
#   'symbol': 'agix',
#   'name': 'SingularityNET',
#   'image': 'https://assets.coingecko.com/coins/images/2138/large/singularitynet.png?1696503103',
#   'current_price': 1.059,
#   'market_cap': 1355761909,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 1475739389,
#   'total_volume': 177001500,
#   'high_24h': 1.1,
#   'low_24h': 1.013,
#   'price_change_24h': -0.04462652379390919,
#   'price_change_percentage_24h': -4.04504,
#   'market_cap_change_24h': -52936756.49194932,
#   'market_cap_change_percentage_24h': -3.75785,
#   'circulating_supply': 1279461512.64262,
#   'total_supply': 1392686826.98352,
#   'max_supply': 2000000000.0,
#   'ath': 1.46,
#   'ath_change_percentage': -27.23075,
#   'ath_date': '2024-03-10T00:24:59.207Z',
#   'atl': 0.00747159,
#   'atl_change_percentage': 14127.78832,
#   'atl_date': '2020-03-13T02:24:16.528Z',
#   'roi': {'times': 9.5861409399,
#    'currency': 'usd',
#    'percentage': 958.61409399},
#   'last_updated': '2024-04-05T20:56:33.237Z'},
#  {'id': 'havven',
#   'symbol': 'snx',
#   'name': 'Synthetix Network',
#   'image': 'https://assets.coingecko.com/coins/images/3406/large/SNX.png?1696504103',
#   'current_price': 3.95,
#   'market_cap': 1295926949,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 1297602988,
#   'total_volume': 41368834,
#   'high_24h': 4.08,
#   'low_24h': 3.86,
#   'price_change_24h': -0.1082823622351472,
#   'price_change_percentage_24h': -2.66622,
#   'market_cap_change_24h': -30068315.47904086,
#   'market_cap_change_percentage_24h': -2.2676,
#   'circulating_supply': 327769196.13952357,
#   'total_supply': 328193104.088774,
#   'max_supply': 328193104.088774,
#   'ath': 28.53,
#   'ath_change_percentage': -86.12043,
#   'ath_date': '2021-02-14T01:12:38.505Z',
#   'atl': 0.0347864,
#   'atl_change_percentage': 11284.21634,
#   'atl_date': '2019-01-06T00:00:00.000Z',
#   'roi': {'times': 6.905965784383516,
#    'currency': 'usd',
#    'percentage': 690.5965784383516},
#   'last_updated': '2024-04-05T20:57:37.280Z'},
#  {'id': 'ether-fi-staked-eth',
#   'symbol': 'eeth',
#   'name': 'ether.fi Staked ETH',
#   'image': 'https://assets.coingecko.com/coins/images/33049/large/ether.fi_eETH.png?1700473063',
#   'current_price': 3308.17,
#   'market_cap': 1293374593,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 3263713771,
#   'total_volume': 396922,
#   'high_24h': 3336.46,
#   'low_24h': 3192.02,
#   'price_change_24h': 28.68,
#   'price_change_percentage_24h': 0.87443,
#   'market_cap_change_24h': -20758372.799780846,
#   'market_cap_change_percentage_24h': -1.57962,
#   'circulating_supply': 391075.9574115929,
#   'total_supply': 986844.796830745,
#   'max_supply': None,
#   'ath': 15396.66,
#   'ath_change_percentage': -78.51989,
#   'ath_date': '2024-03-24T04:26:06.292Z',
#   'atl': 2155.76,
#   'atl_change_percentage': 53.41334,
#   'atl_date': '2024-02-08T11:26:30.368Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:42.367Z'},
#  {'id': 'ordinals',
#   'symbol': 'ordi',
#   'name': 'ORDI',
#   'image': 'https://assets.coingecko.com/coins/images/30162/large/ordi.png?1696529082',
#   'current_price': 60.65,
#   'market_cap': 1274599240,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 1274599240,
#   'total_volume': 383764232,
#   'high_24h': 64.33,
#   'low_24h': 58.2,
#   'price_change_24h': -2.1936937628332487,
#   'price_change_percentage_24h': -3.49073,
#   'market_cap_change_24h': -41732608.87157655,
#   'market_cap_change_percentage_24h': -3.17037,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': None,
#   'ath': 95.52,
#   'ath_change_percentage': -36.32829,
#   'ath_date': '2024-03-05T01:45:22.816Z',
#   'atl': 2.86,
#   'atl_change_percentage': 2025.87251,
#   'atl_date': '2023-09-11T15:22:32.140Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:33.870Z'},
#  {'id': 'chiliz',
#   'symbol': 'chz',
#   'name': 'Chiliz',
#   'image': 'https://assets.coingecko.com/coins/images/8834/large/CHZ_Token_updated.png?1696508986',
#   'current_price': 0.141864,
#   'market_cap': 1261420838,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 1261420838,
#   'total_volume': 100763618,
#   'high_24h': 0.144805,
#   'low_24h': 0.135833,
#   'price_change_24h': 0.00033369,
#   'price_change_percentage_24h': 0.23577,
#   'market_cap_change_24h': 4794394,
#   'market_cap_change_percentage_24h': 0.38153,
#   'circulating_supply': 8888888888.0,
#   'total_supply': 8888888888.0,
#   'max_supply': 8888888888.0,
#   'ath': 0.878633,
#   'ath_change_percentage': -83.82128,
#   'ath_date': '2021-03-13T08:04:21.200Z',
#   'atl': 0.00410887,
#   'atl_change_percentage': 3359.62359,
#   'atl_date': '2019-09-28T00:00:00.000Z',
#   'roi': {'times': 5.448354055306605,
#    'currency': 'usd',
#    'percentage': 544.8354055306604},
#   'last_updated': '2024-04-05T20:57:14.884Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'image': 'https://assets.coingecko.com/coins/images/976/large/Tezos-logo.png?1696502091',
#   'current_price': 1.26,
#   'market_cap': 1230628833,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 1256593702,
#   'total_volume': 36610268,
#   'high_24h': 1.27,
#   'low_24h': 1.21,
#   'price_change_24h': -0.001257206098326025,
#   'price_change_percentage_24h': -0.0997,
#   'market_cap_change_24h': 3042919,
#   'market_cap_change_percentage_24h': 0.24788,
#   'circulating_supply': 977125772.651386,
#   'total_supply': 997744465.325447,
#   'max_supply': None,
#   'ath': 9.12,
#   'ath_change_percentage': -86.14646,
#   'ath_date': '2021-10-04T00:41:18.025Z',
#   'atl': 0.350476,
#   'atl_change_percentage': 260.33773,
#   'atl_date': '2018-12-07T00:00:00.000Z',
#   'roi': {'times': 1.6802745347744765,
#    'currency': 'usd',
#    'percentage': 168.02745347744766},
#   'last_updated': '2024-04-05T20:57:17.846Z'},
#  {'id': 'worldcoin-wld',
#   'symbol': 'wld',
#   'name': 'Worldcoin',
#   'image': 'https://assets.coingecko.com/coins/images/31069/large/worldcoin.jpeg?1696529903',
#   'current_price': 6.92,
#   'market_cap': 1227364015,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 69335630332,
#   'total_volume': 213060517,
#   'high_24h': 6.97,
#   'low_24h': 6.51,
#   'price_change_24h': 0.02283998,
#   'price_change_percentage_24h': 0.33101,
#   'market_cap_change_24h': 15506031,
#   'market_cap_change_percentage_24h': 1.27953,
#   'circulating_supply': 177017791.509361,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 11.74,
#   'ath_change_percentage': -40.89114,
#   'ath_date': '2024-03-10T00:10:42.330Z',
#   'atl': 0.973104,
#   'atl_change_percentage': 613.15546,
#   'atl_date': '2023-09-13T07:36:44.064Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:40.560Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://assets.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 8.51,
#   'market_cap': 1226364692,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 3029103393,
#   'total_volume': 15828764,
#   'high_24h': 8.66,
#   'low_24h': 8.32,
#   'price_change_24h': 0.04758255,
#   'price_change_percentage_24h': 0.562,
#   'market_cap_change_24h': 5939891,
#   'market_cap_change_percentage_24h': 0.48671,
#   'circulating_supply': 144118517.10815412,
#   'total_supply': 355970693.0,
#   'max_supply': 400000000.0,
#   'ath': 14.64,
#   'ath_change_percentage': -41.88807,
#   'ath_date': '2022-10-28T12:32:18.119Z',
#   'atl': 3.06,
#   'atl_change_percentage': 177.9575,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:36.957Z'},
#  {'id': 'pyth-network',
#   'symbol': 'pyth',
#   'name': 'Pyth Network',
#   'image': 'https://assets.coingecko.com/coins/images/31924/large/pyth.png?1701245725',
#   'current_price': 0.813585,
#   'market_cap': 1220746985,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 8138313235,
#   'total_volume': 116078901,
#   'high_24h': 0.856749,
#   'low_24h': 0.779622,
#   'price_change_24h': -0.03873743130874063,
#   'price_change_percentage_24h': -4.54493,
#   'market_cap_change_24h': -56655378.70370722,
#   'market_cap_change_percentage_24h': -4.4352,
#   'circulating_supply': 1500000000.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 1.2,
#   'ath_change_percentage': -31.91319,
#   'ath_date': '2024-03-16T07:01:15.357Z',
#   'atl': 0.228806,
#   'atl_change_percentage': 256.00813,
#   'atl_date': '2024-01-08T03:29:54.594Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:57:41.444Z'},
#  {'id': 'ronin',
#   'symbol': 'ron',
#   'name': 'Ronin',
#   'image': 'https://assets.coingecko.com/coins/images/20009/large/14101.png?1711464498',
#   'current_price': 3.77,
#   'market_cap': 1173032493,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 3775008090,
#   'total_volume': 22631330,
#   'high_24h': 3.8,
#   'low_24h': 3.61,
#   'price_change_24h': -0.010444771111865592,
#   'price_change_percentage_24h': -0.27596,
#   'market_cap_change_24h': 1225223,
#   'market_cap_change_percentage_24h': 0.10456,
#   'circulating_supply': 310736418.312653,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 4.45,
#   'ath_change_percentage': -15.12238,
#   'ath_date': '2024-03-26T05:12:38.487Z',
#   'atl': 0.196601,
#   'atl_change_percentage': 1821.44846,
#   'atl_date': '2022-11-21T19:36:31.487Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:45.709Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://assets.coingecko.com/coins/images/738/large/eos-eos-logo.png?1696501893',
#   'current_price': 1.003,
#   'market_cap': 1147868161,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': None,
#   'total_volume': 133346415,
#   'high_24h': 1.003,
#   'low_24h': 0.953957,
#   'price_change_24h': 0.02332172,
#   'price_change_percentage_24h': 2.38018,
#   'market_cap_change_24h': 28147504,
#   'market_cap_change_percentage_24h': 2.5138,
#   'circulating_supply': 1145490447.1868,
#   'total_supply': None,
#   'max_supply': None,
#   'ath': 22.71,
#   'ath_change_percentage': -95.58278,
#   'ath_date': '2018-04-29T07:50:33.540Z',
#   'atl': 0.5024,
#   'atl_change_percentage': 99.68312,
#   'atl_date': '2017-10-23T00:00:00.000Z',
#   'roi': {'times': 0.013286501701137375,
#    'currency': 'usd',
#    'percentage': 1.3286501701137374},
#   'last_updated': '2024-04-05T20:57:07.371Z'},
#  {'id': 'mina-protocol',
#   'symbol': 'mina',
#   'name': 'Mina Protocol',
#   'image': 'https://assets.coingecko.com/coins/images/15628/large/JM4_vQ34_400x400.png?1696515261',
#   'current_price': 1.061,
#   'market_cap': 1146972827,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 1213715171,
#   'total_volume': 34274776,
#   'high_24h': 1.089,
#   'low_24h': 1.016,
#   'price_change_24h': -0.021114282799148842,
#   'price_change_percentage_24h': -1.952,
#   'market_cap_change_24h': -23833885.0222497,
#   'market_cap_change_percentage_24h': -2.03568,
#   'circulating_supply': 1080994242.84004,
#   'total_supply': 1143897292.84004,
#   'max_supply': None,
#   'ath': 9.09,
#   'ath_change_percentage': -88.30044,
#   'ath_date': '2021-06-01T01:42:37.064Z',
#   'atl': 0.351341,
#   'atl_change_percentage': 202.7058,
#   'atl_date': '2023-10-11T04:00:22.740Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:36.111Z'},
#  {'id': 'tokenize-xchange',
#   'symbol': 'tkx',
#   'name': 'Tokenize Xchange',
#   'image': 'https://assets.coingecko.com/coins/images/4984/large/TKX_-_Logo_-_RGB-15.png?1696505519',
#   'current_price': 14.3,
#   'market_cap': 1143832083,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 1429861598,
#   'total_volume': 62228425,
#   'high_24h': 14.59,
#   'low_24h': 13.93,
#   'price_change_24h': -0.2279206497402928,
#   'price_change_percentage_24h': -1.56913,
#   'market_cap_change_24h': -17458611.334104776,
#   'market_cap_change_percentage_24h': -1.50338,
#   'circulating_supply': 79995999.94518414,
#   'total_supply': 100000000.0,
#   'max_supply': 100000000.0,
#   'ath': 22.3,
#   'ath_change_percentage': -35.52216,
#   'ath_date': '2022-10-31T10:23:59.455Z',
#   'atl': 0.111255,
#   'atl_change_percentage': 12821.81963,
#   'atl_date': '2019-04-28T00:00:00.000Z',
#   'roi': {'times': 48.21655759600031,
#    'currency': 'usd',
#    'percentage': 4821.655759600031},
#   'last_updated': '2024-04-05T20:55:42.666Z'},
#  {'id': 'ondo-finance',
#   'symbol': 'ondo',
#   'name': 'Ondo',
#   'image': 'https://assets.coingecko.com/coins/images/26580/large/ONDO.png?1696525656',
#   'current_price': 0.788157,
#   'market_cap': 1137856081,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 7881173843,
#   'total_volume': 148998847,
#   'high_24h': 0.809904,
#   'low_24h': 0.738293,
#   'price_change_24h': -0.006493106564268047,
#   'price_change_percentage_24h': -0.8171,
#   'market_cap_change_24h': -12413915.75594759,
#   'market_cap_change_percentage_24h': -1.07922,
#   'circulating_supply': 1443764727.588207,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 1.047,
#   'ath_change_percentage': -24.31512,
#   'ath_date': '2024-03-31T20:06:01.958Z',
#   'atl': 0.082171,
#   'atl_change_percentage': 864.25082,
#   'atl_date': '2024-01-18T12:14:30.524Z',
#   'roi': None,
#   'last_updated': '2024-04-05T20:56:47.172Z'}]

# %%
coins = []

for i in range(3):
    response = requests.get(f"{url}/per_page=100&page={i}", headers=headers)
    coins_batch = response.json()
    coins += coins_batch

# %%
len(coins)
# Out:
# 102

# %%
# coin_to_description = {}

# %%
response = requests.get(f"{info_url}/{coins[0]['id']}?localization=false&tickers=false&market_data=false&community_data=false&developer_data=false", headers=headers)

# %%
response.json()
# Out:
# {'status': {'error_code': 429,
#   'error_message': "You've exceeded the Rate Limit. Please visit https://www.coingecko.com/en/api/pricing to subscribe to our API plans for higher rate limits."}}

# %%
for i, coin in enumerate(coins[66:500]):
    response = requests.get(f"{info_url}/{coin['id']}?localization=false&tickers=false&market_data=false&community_data=false&developer_data=false", headers=headers)
    coin_data = response.json()
    print(coin_data)
    description = coin_data['description']['en']
    coin_to_description[coin['id']] = description
    if i % 5 == 0:
        time.sleep(61)

# %%
len(coin_to_description)

# %%
import json

# %%
with open("../data/coin-description.json", "w") as f:
    json.dump(coin_to_description, f)

# %%
len(coins)

# %%
result = requests.get("https://token.jup.ag/strict").json()

# %%
address_to_token = {}

# %%
for token in result:
    address = token['address']
    address_to_token[address] = token

# %%
be_coins = []

# %%
import tqdm

# %%
for i in range(100):
    coins = requests.get(
        f'https://public-api.birdeye.so/public/tokenlist?sort_by=mc&sort_type=desc&offset={i*50}&limit=50', 
        headers={"x-chain": "solana", "X-API-KEY": "9f0fc8d9eb0f42758e36ea3f71bec8d6"}
    ).json()
    be_coins += coins['data']['tokens']

# %%
len(be_coins)

# %%
be_coins

# %%
result = []

# %%
sym_set = set()

# %%
x = 0
for coin in be_coins:
    
    if coin['address'] in address_to_token and (symbol := address_to_token[coin['address']]['symbol'].lower()) not in sym_set:
        result.append({
            "symbol": symbol,
            "address": coin['address'],
        })
        sym_set.add(symbol)
        if len(result) >= 10:
            break

# %%
import json
with open("../data/coins-list.json", "w") as f:
    json.dump(result, f)

# %%
result
